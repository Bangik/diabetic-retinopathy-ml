# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('E:/Pawang Code/Diabetic Retinopathy/featureExtraction3.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Image            500 non-null    object
#  1   contrast_0       500 non-null    float64
#  2   dissimilarity_0  500 non-null    float64
#  3   homogeneity_0    500 non-null    float64
#  4   ASM_0            500 non-null    float64
#  5   energy_0         500 non-null    float64
#  6   correlation_0    500 non-null    float64
#  7   Label            500 non-null    int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 31.4+ KB

# %%
x = np.arange(100)
y0 = df.loc[df['Label'] == 0]['homogeneity_0']
y1 = df.loc[df['Label'] == 1]['homogeneity_0']
y2 = df.loc[df['Label'] == 2]['dissimilarity_0']
y3 = df.loc[df['Label'] == 3]['dissimilarity_0']
y4 = df.loc[df['Label'] == 4]['dissimilarity_0']

f = plt.figure()
f.set_figwidth(25)
f.set_figheight(12)

plt.plot(x, y0, 'r', label='No DR')
plt.plot(x, y1, 'g', label='Mild')
# plt.plot(x, y2, 'b', label='Moderate')
# plt.plot(x, y3, 'y', label='Severe')
# plt.plot(x, y4, 'k', label='Proliferative DR')
plt.xlabel('Jumlah Data')
plt.ylabel('Contrast')
plt.title('Contrast')
plt.legend()
plt.show()

# %%
# display dataset multiclass classification with seaborn scatterplot
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_excel('E:/Pawang Code/Diabetic Retinopathy/featureExtractionbv.xlsx')
df.info()

sns.set(style="ticks", color_codes=True)
sns.pairplot(df, hue="Label", palette="husl")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3661 entries, 0 to 3660
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Image            3661 non-null   object
#  1   contrast_0       3661 non-null   float64
#  2   dissimilarity_0  3661 non-null   float64
#  3   homogeneity_0    3661 non-null   float64
#  4   ASM_0            3661 non-null   float64
#  5   energy_0         3661 non-null   float64
#  6   correlation_0    3661 non-null   float64
#  7   Label            3661 non-null   int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 228.9+ KB
